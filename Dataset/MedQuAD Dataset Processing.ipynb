# %% [markdown]
# # Fine-Tuning Llama 3.1 8B using QLoRa for Healthcare Q&A - MedQuAD Dataset
#
# ###Jade Webb
#
# ###Jun 2026
#
# ###References:
#
# ###Dataset: https://www.kaggle.com/datasets/jpmiller/layoutlm

# %% [markdown]
# ## Installations and Imports

# %%
import pandas as pd
from datasets import Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##Load and Inspect MedQuAD Dataset

# %%
file_path = '/content/drive/MyDrive/Colab Notebooks/QLoRa/medquad.csv'

# %%
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#                                  question  \
# 0                What is (are) Glaucoma ?
# 1                  What causes Glaucoma ?
# 2     What are the symptoms of Glaucoma ?
# 3  What are the treatments for Glaucoma ?
# 4                What is (are) Glaucoma ?
#
#                                               answer           source  \
# 0  Glaucoma is a group of diseases that can damag...  NIHSeniorHealth
# 1  Nearly 2.7 million people have glaucoma, a lea...  NIHSeniorHealth
# 2  Symptoms of Glaucoma  Glaucoma can develop in ...  NIHSeniorHealth
# 3  Although open-angle glaucoma cannot be cured, ...  NIHSeniorHealth
# 4  Glaucoma is a group of diseases that can damag...  NIHSeniorHealth
#
#   focus_area
# 0   Glaucoma
# 1   Glaucoma
# 2   Glaucoma
# 3   Glaucoma
# 4   Glaucoma

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16412 entries, 0 to 16411
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   question    16412 non-null  object
#  1   answer      16407 non-null  object
#  2   source      16412 non-null  object
#  3   focus_area  16398 non-null  object
# dtypes: object(4)
# memory usage: 513.0+ KB

# %% [markdown]
# ###Null

# %%
df = df.dropna(axis=0)

# %% [markdown]
# ###Duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(48)

# %%
df = df.drop_duplicates()

# %% [markdown]
# ### Irrelevant Columns

# %%
df = df.drop({"source", "focus_area"}, axis=1)

# %% [markdown]
# ## Save Dataset

# %%
df.head()
# Out:
#                                  question  \
# 0                What is (are) Glaucoma ?
# 1                  What causes Glaucoma ?
# 2     What are the symptoms of Glaucoma ?
# 3  What are the treatments for Glaucoma ?
# 4                What is (are) Glaucoma ?
#
#                                               answer
# 0  Glaucoma is a group of diseases that can damag...
# 1  Nearly 2.7 million people have glaucoma, a lea...
# 2  Symptoms of Glaucoma  Glaucoma can develop in ...
# 3  Although open-angle glaucoma cannot be cured, ...
# 4  Glaucoma is a group of diseases that can damag...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16345 entries, 0 to 16411
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   question  16345 non-null  object
#  1   answer    16345 non-null  object
# dtypes: object(2)
# memory usage: 383.1+ KB

# %%
dataset = Dataset.from_pandas(df)

# %%
dataset.save_to_disk('/content/drive/MyDrive/Colab Notebooks/QLoRa/medquad_dataset')
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/16345 [00:00<?, ? examples/s]
